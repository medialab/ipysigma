# %%
import networkx as nx
from ipysigma import Sigma

# %%
g = nx.karate_club_graph()
from random import random
categ = {}
for k, a in g.nodes(data=True):
    a['size'] = 20 * random()
    a['random'] = random()
    categ[k] = random() > 0.5
for _, _, a in g.edges(data=True):
    a['random'] = random()
    a['partition'] = random() > 0.5
    a['label'] = 'Test'
sigma = Sigma(
    g,
    node_size=g.degree,
    node_size_range=[5, 10],
    node_color=categ,
    node_label='club',
    edge_color='partition',
    edge_label='label',
    edge_size='random',
    clickable_edges=True
)
sigma
# Out:
# Sigma(nx.Graph with 34 nodes and 78 edges)

# %%
g = nx.read_gexf('./data/rio.gexf')
Sigma(g, node_color='Nature of institution', node_label='Label2', node_size=g.degree)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4f61974010ff> in <module>
# ----> 1 g = nx.read_gexf('./data/rio.gexf')
#       2 Sigma(g, node_color='Nature of institution', node_label='Label2', node_size=g.degree)
#
# NameError: name 'nx' is not defined

# %%
g = nx.MultiGraph()
g.add_edge(1, 2)
g.add_edge(4, 5, size=10)
g.add_edge(2, 3, key='test', size=20)
Sigma(g, clickable_edges=True)
# Out:
# Sigma(nx.MultiGraph with 5 nodes and 3 edges)
