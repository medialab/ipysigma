# %%
import networkx as nx
from ipysigma import Sigma

# %%
g = nx.read_gexf('arctic.gexf')

# %%
Sigma(g)
# Out:
# Sigma(value={'nodes': [('0', {'nodedef': 'n0', 'label': '1831', 'occurrences': 1, 'viz': {'color': {'r': 255, …
