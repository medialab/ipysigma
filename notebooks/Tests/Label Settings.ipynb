# %%
import networkx as nx
from ipysigma import Sigma

# %%
g = nx.karate_club_graph()

# %%
Sigma(g, default_node_size=10, show_all_labels=True, edge_label=lambda u, v: '%s--%s' % (u, v))
# Out:
# Sigma(nx.Graph with 34 nodes and 78 edges)
